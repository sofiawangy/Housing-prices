# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
#Read data

train = pd.read_csv('train.csv', index_col = 0)
test = pd.read_csv('test.csv', index_col = 0)

train.shape
# Out:
# (1460, 80)

# %%
test.shape
# Out:
# (1459, 79)

# %%
sns.distplot(train.SalePrice);
np.mean(train.SalePrice)
# Out:
# 180921.19589041095

# %%
skew = train.skew()
kurt = train.kurt() 
corr = train.corr()['SalePrice']
cols = ['skew', 'kurt', 'corr']
details = pd.concat([skew, kurt, corr], axis = 1, sort=False)
details.columns = cols
details[details['corr'] >= 0.2].sort_values(['corr', 'kurt'], ascending = False)
# details.shape
# Out:
#                    skew        kurt      corr
# SalePrice      1.882876    6.536282  1.000000
# OverallQual    0.216944    0.096293  0.790982
# GrLivArea      1.366560    4.895121  0.708624
# GarageCars    -0.342549    0.220998  0.640409
# GarageArea     0.179981    0.917067  0.623431
# TotalBsmtSF    1.524255   13.250483  0.613581
# 1stFlrSF       1.376757    5.745841  0.605852
# FullBath       0.036562   -0.857043  0.560664
# TotRmsAbvGrd   0.676341    0.880762  0.533723
# YearBuilt     -0.613461   -0.439552  0.522897
# YearRemodAdd  -0.503562   -1.272245  0.507101
# GarageYrBlt   -0.649415   -0.418341  0.486362
# MasVnrArea     2.669084   10.082417  0.477493
# Fireplaces     0.649565   -0.217237  0.466929
# BsmtFinSF1     1.685503   11.118236  0.386420
# LotFrontage    2.163569   17.452867  0.351799
# WoodDeckSF     1.541376    2.992951  0.324413
# 2ndFlrSF       0.813030   -0.553464  0.319334
# OpenPorchSF    2.364342    8.490336  0.315856
# HalfBath       0.675897   -1.076927  0.284108
# LotArea       12.207688  203.243271  0.263843
# BsmtFullBath   0.596067   -0.839098  0.227122
# BsmtUnfSF      0.920268    0.474994  0.214479

# %%
fig = plt.figure(figsize=(20, 5))

fig1 = fig.add_subplot(131); 
sns.distplot(train.OverallQual);

fig2 = fig.add_subplot(132); 
sns.distplot(train.GrLivArea);

plt.tight_layout(); 
plt.show()

# %%
fig = plt.figure(figsize=(20, 15))
sns.set(font_scale=1.5)

fig1 = fig.add_subplot(221); 
sns.boxplot(x='OverallQual', y='SalePrice', data=train[['SalePrice', 'OverallQual']])

fig2 = fig.add_subplot(222); 
sns.scatterplot(x = train.GrLivArea, y = train.SalePrice, hue=train.OverallQual, palette= 'Spectral')

fig3 = fig.add_subplot(223); 
sns.scatterplot(x = train.GarageCars, y = train.SalePrice, hue=train.OverallQual, palette= 'Spectral')

fig4 = fig.add_subplot(224); 
sns.scatterplot(x = train.GarageArea, y = train.SalePrice, hue=train.OverallQual, palette= 'Spectral')

plt.tight_layout(); 
plt.show()

# %%
train_sub = train.drop(train[(train.GrLivArea>4000) & (train.SalePrice<300000)].index)
corr = train_sub.corr()['SalePrice'].sort_values(ascending = False)
corr.head()
# Out:
# SalePrice      1.000000
# OverallQual    0.795774
# GrLivArea      0.734968
# TotalBsmtSF    0.651153
# GarageCars     0.641047
# Name: SalePrice, dtype: float64

# %%
temp = train_sub[['SalePrice', 'GrLivArea', 'TotRmsAbvGrd']]
temp['GrLivAreaByRms'] = temp.GrLivArea/temp.TotRmsAbvGrd
temp['GrLivArea_x_Rms'] = temp.GrLivArea*temp.TotRmsAbvGrd
# Out:
# /home/sofiawangy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sofiawangy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig = plt.figure(figsize=(20,5))
fig1 = fig.add_subplot(121); 
sns.regplot(x='GrLivAreaByRms', y='SalePrice', data=temp)

fig2 = fig.add_subplot(122); 
sns.regplot(x='GrLivArea_x_Rms', y='SalePrice', data=temp)
# plt.legend(['Outliers'])
plt.show()

# %%
max(temp['GrLivArea_x_Rms'])
train_sub = train_sub[train_sub.GrLivArea * train_sub.TotRmsAbvGrd < 45000]

# %%
fig = plt.figure(figsize=(20,5))

fig1 = fig.add_subplot(131); 
sns.boxplot(train_sub.GarageCars)

fig2 = fig.add_subplot(132); 
sns.boxplot(train_sub.GarageArea)

fig3 = fig.add_subplot(133); 
sns.regplot(x='GarageCars', y='GarageArea', data=train_sub)
# sns.boxplot(train_sub.GarageCars, train_sub.GarageArea)

plt.show()

# %%
temp = train_sub[['SalePrice', 'GarageArea', 'GarageCars']]
temp['GarageAreaByCar'] = temp.GarageArea/temp.GarageCars
temp['GarageArea_x_Car'] = temp.GarageArea*temp.GarageCars

fig = plt.figure(figsize=(20,5))

fig1 = fig.add_subplot(121); 
sns.regplot(x='GarageAreaByCar', y='SalePrice', data=temp)

fig2 = fig.add_subplot(122); 
sns.regplot(x='GarageArea_x_Car', y='SalePrice', data=temp); 

plt.show()
# Out:
# /home/sofiawangy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sofiawangy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig = plt.figure(figsize=(20,5))
sns.regplot(x='GarageArea_x_Car', y='SalePrice', data=temp); 
plt.xlim(3500,)
plt.show()

# %%
train_sub = train_sub.loc[temp.GarageArea_x_Car<3700]

# %%
#set features and target

x_train = train_sub.iloc[:, :-1]
target = train_sub.iloc[:, -1]

#Define continuous and categorical variables

cont =['LotFrontage', 'LotArea', 'MasVnrArea', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 
       'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 
       'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath']

cat = list(set(x_train.columns) - set(cont))

# %%
data = pd.concat([train_sub, test]).reset_index(drop=True)
data.shape
# data.head()
# Out:
# /home/sofiawangy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (2912, 80)

# %%
for i in cat:
    print(data[i].value_counts().sort_index())
# Out:
# N     196
# Y    2716
# Name: CentralAir, dtype: int64
# 1.5Fin     314
# 1.5Unf      19
# 1Story    1468
# 2.5Fin       7
# 2.5Unf      24
# 2Story     869
# SFoyer      83
# SLvl       128
# Name: HouseStyle, dtype: int64
# Ex      12
# Fa      67
# Gd     298
# Po       3
# TA    2532
# Name: ExterCond, dtype: int64
# AllPub    2909
# NoSeWa       1
# Name: Utilities, dtype: int64
# Av     417
# Gd     274
# Mn     239
# No    1900
# Name: BsmtExposure, dtype: int64
# Blmngtn     28
# Blueste     10
# BrDale      30
# BrkSide    108
# ClearCr     44
# CollgCr    267
# Crawfor    103
# Edwards    192
# Gilbert    165
# IDOTRR      92
# MeadowV     37
# Mitchel    113
# NAmes      442
# NPkVill     23
# NWAmes     131
# NoRidge     71
# NridgHt    165
# OldTown    239
# SWISU       47
# Sawyer     151
# SawyerW    125
# Somerst    182
# StoneBr     51
# Timber      72
# Veenker     24
# Name: Neighborhood, dtype: int64
# Maj1      19
# Maj2       9
# Min1      65
# Min2      70
# Mod       35
# Sev        2
# Typ     2710
# Name: Functional, dtype: int64
# 2006    619
# 2007    689
# 2008    620
# 2009    645
# 2010    339
# Name: YrSold, dtype: int64
# C (all)      24
# FV          139
# RH           25
# RL         2260
# RM          460
# Name: MSZoning, dtype: int64
# Ex     43
# Fa     74
# Gd    741
# Po     46
# TA    591
# Name: FireplaceQu, dtype: int64
# BrkTil     311
# CBlock    1231
# PConc     1305
# Slab        49
# Stone       11
# Wood         5
# Name: Foundation, dtype: int64
# COD        87
# CWD        12
# Con         5
# ConLD      25
# ConLI       9
# ConLw       8
# New       236
# Oth         7
# WD       2522
# Name: SaleType, dtype: int64
# Grvl      11
# Pave    2901
# Name: Street, dtype: int64
# FuseA     187
# FuseF      50
# FuseP       8
# Mix         1
# SBrkr    2665
# Name: Electrical, dtype: int64
# Ex       3
# Fa     124
# Gd      24
# Po       5
# TA    2598
# Name: GarageQual, dtype: int64
# 1872      1
# 1875      1
# 1879      1
# 1880      5
# 1882      1
# 1885      2
# 1890      7
# 1892      2
# 1893      1
# 1895      3
# 1896      1
# 1898      1
# 1900     29
# 1901      2
# 1902      1
# 1904      1
# 1905      3
# 1906      1
# 1907      1
# 1908      2
# 1910     43
# 1911      1
# 1912      5
# 1913      1
# 1914      7
# 1915     24
# 1916     10
# 1917      3
# 1918     10
# 1919      5
#        ...
# 1981      9
# 1982      7
# 1983      8
# 1984     19
# 1985      7
# 1986     10
# 1987      8
# 1988     15
# 1989      8
# 1990     19
# 1991     12
# 1992     27
# 1993     39
# 1994     37
# 1995     31
# 1996     34
# 1997     35
# 1998     46
# 1999     52
# 2000     48
# 2001     35
# 2002     47
# 2003     88
# 2004     99
# 2005    142
# 2006    138
# 2007    108
# 2008     47
# 2009     25
# 2010      3
# Name: YearBuilt, Length: 118, dtype: int64
# 1     121
# 2     133
# 3     230
# 4     279
# 5     394
# 6     503
# 7     446
# 8     230
# 9     158
# 10    172
# 11    142
# 12    104
# Name: MoSold, dtype: int64
# Artery       5
# Feedr       13
# Norm      2883
# PosA         4
# PosN         3
# RRAe         1
# RRAn         1
# RRNn         2
# Name: Condition2, dtype: int64
# Flat         20
# Gable      2307
# Gambrel      22
# Hip         547
# Mansard      11
# Shed          5
# Name: RoofStyle, dtype: int64
# Fa     103
# Gd     122
# Po       5
# TA    2600
# Name: BsmtCond, dtype: int64
# 1       7
# 2      10
# 3      50
# 4      99
# 5    1641
# 6     531
# 7     389
# 8     144
# 9      41
# Name: OverallCond, dtype: int64
# BrkCmn       25
# BrkFace     877
# None       1740
# Stone       246
# Name: MasVnrType, dtype: int64
# ALQ      52
# BLQ      68
# GLQ      34
# LwQ      87
# Rec     105
# Unf    2486
# Name: BsmtFinType2, dtype: int64
# Gar2     5
# Othr     4
# Shed    94
# TenC     1
# Name: MiscFeature, dtype: int64
# Gtl    2772
# Mod     124
# Sev      16
# Name: LandSlope, dtype: int64
# GdPrv    118
# GdWo     112
# MnPrv    329
# MnWw      12
# Name: Fence, dtype: int64
# Grvl    120
# Pave     77
# Name: Alley, dtype: int64
# Floor       1
# GasA     2867
# GasW       27
# Grav        9
# OthW        2
# Wall        6
# Name: Heating, dtype: int64
# Ex    4
# Fa    2
# Gd    3
# Name: PoolQC, dtype: int64
# N     215
# P      62
# Y    2635
# Name: PavedDrive, dtype: int64
# Fin     716
# RFn     809
# Unf    1229
# Name: GarageFinish, dtype: int64
# 1       4
# 2      13
# 3      39
# 4     225
# 5     824
# 6     730
# 7     600
# 8     341
# 9     107
# 10     29
# Name: OverallQual, dtype: int64
# Ex     104
# Fa      33
# Gd     979
# TA    1796
# Name: ExterQual, dtype: int64
# 20     1078
# 30      138
# 40        6
# 45       18
# 50      287
# 60      573
# 70      128
# 75       23
# 80      118
# 85       48
# 90      108
# 120     182
# 150       1
# 160     128
# 180      17
# 190      59
# Name: MSSubClass, dtype: int64
# AsbShng      38
# AsphShn       4
# Brk Cmn      22
# BrkFace      47
# CBlock        3
# CmentBd     125
# HdBoard     406
# ImStucc      15
# MetalSd     444
# Other         1
# Plywood     270
# Stone         6
# Stucco       46
# VinylSd    1012
# Wd Sdng     391
# Wd Shng      81
# Name: Exterior2nd, dtype: int64
# 1Fam      2421
# 2fmCon      60
# Duplex     108
# Twnhs       96
# TwnhsE     227
# Name: BldgType, dtype: int64
# AsbShng      44
# AsphShn       2
# BrkComm       6
# BrkFace      87
# CBlock        2
# CemntBd     125
# HdBoard     442
# ImStucc       1
# MetalSd     447
# Plywood     221
# Stone         2
# Stucco       42
# VinylSd    1023
# Wd Sdng     411
# WdShing      56
# Name: Exterior1st, dtype: int64
# Ex       3
# Fa      74
# Gd      15
# Po      14
# TA    2648
# Name: GarageCond, dtype: int64
# 1895.0      1
# 1896.0      1
# 1900.0      6
# 1906.0      1
# 1908.0      1
# 1910.0     10
# 1914.0      2
# 1915.0      7
# 1916.0      6
# 1917.0      2
# 1918.0      3
# 1919.0      1
# 1920.0     33
# 1921.0      5
# 1922.0      8
# 1923.0      6
# 1924.0      8
# 1925.0     15
# 1926.0     15
# 1927.0      5
# 1928.0      7
# 1929.0      2
# 1930.0     27
# 1931.0      4
# 1932.0      4
# 1933.0      1
# 1934.0      4
# 1935.0      8
# 1936.0      7
# 1937.0      6
#          ...
# 1982.0      9
# 1983.0     11
# 1984.0     19
# 1985.0     18
# 1986.0     12
# 1987.0     18
# 1988.0     20
# 1989.0     19
# 1990.0     26
# 1991.0     17
# 1992.0     27
# 1993.0     49
# 1994.0     38
# 1995.0     35
# 1996.0     40
# 1997.0     44
# 1998.0     58
# 1999.0     54
# 2000.0     55
# 2001.0     41
# 2002.0     53
# 2003.0     92
# 2004.0     99
# 2005.0    142
# 2006.0    115
# 2007.0    114
# 2008.0     60
# 2009.0     28
# 2010.0      5
# 2207.0      1
# Name: GarageYrBlt, Length: 103, dtype: int64
# 1950    360
# 1951     14
# 1952     15
# 1953     20
# 1954     28
# 1955     25
# 1956     30
# 1957     20
# 1958     34
# 1959     30
# 1960     29
# 1961     24
# 1962     26
# 1963     30
# 1964     26
# 1965     28
# 1966     27
# 1967     34
# 1968     39
# 1969     25
# 1970     44
# 1971     31
# 1972     35
# 1973     21
# 1974     19
# 1975     29
# 1976     48
# 1977     46
# 1978     36
# 1979     24
#        ...
# 1981     12
# 1982      9
# 1983     11
# 1984     19
# 1985     14
# 1986     12
# 1987     16
# 1988     15
# 1989     18
# 1990     29
# 1991     29
# 1992     32
# 1993     43
# 1994     53
# 1995     55
# 1996     59
# 1997     49
# 1998     77
# 1999     60
# 2000    104
# 2001     49
# 2002     82
# 2003     99
# 2004    111
# 2005    141
# 2006    202
# 2007    164
# 2008     79
# 2009     33
# 2010     13
# Name: YearRemodAdd, Length: 61, dtype: int64
# Corner      510
# CulDSac     176
# FR2          85
# FR3          14
# Inside     2127
# Name: LotConfig, dtype: int64
# Abnorml     189
# AdjLand      12
# Alloca       24
# Family       46
# Normal     2399
# Partial     242
# Name: SaleCondition, dtype: int64
# CompShg    2870
# Membran       1
# Metal         1
# Roll          1
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Name: RoofMatl, dtype: int64
# IR1     967
# IR2      76
# IR3      15
# Reg    1854
# Name: LotShape, dtype: int64
# 2Types       22
# Attchd     1721
# Basment      36
# BuiltIn     185
# CarPort      15
# Detchd      777
# Name: GarageType, dtype: int64
# ALQ    429
# BLQ    268
# GLQ    847
# LwQ    152
# Rec    288
# Unf    849
# Name: BsmtFinType1, dtype: int64
# Ex     255
# Fa      88
# Gd    1209
# TA    1279
# Name: BsmtQual, dtype: int64
# Bnk     114
# HLS     120
# Low      58
# Lvl    2620
# Name: LandContour, dtype: int64
# Ex    1488
# Fa      92
# Gd     474
# Po       3
# TA     855
# Name: HeatingQC, dtype: int64
# Ex     202
# Fa      69
# Gd    1151
# TA    1489
# Name: KitchenQual, dtype: int64
# Artery      91
# Feedr      162
# Norm      2508
# PosA        20
# PosN        38
# RRAe        28
# RRAn        50
# RRNe         6
# RRNn         9
# Name: Condition1, dtype: int64

# %%
data.GarageYrBlt[data.GarageYrBlt == 2207] = 2007
# Out:
# /home/sofiawangy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.drop('Utilities', axis=1)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0          856       854          0   NaN             3     1Fam       TA
# 1         1262         0          0   NaN             3     1Fam       TA
# 2          920       866          0   NaN             3     1Fam       TA
# 3          961       756          0   NaN             3     1Fam       Gd
# 4         1145      1053          0   NaN             4     1Fam       TA
# 5          796       566        320   NaN             1     1Fam       TA
# 6         1694         0          0   NaN             3     1Fam       TA
# 7         1107       983          0   NaN             3     1Fam       TA
# 8         1022       752          0   NaN             2     1Fam       TA
# 9         1077         0          0   NaN             2   2fmCon       TA
# 10        1040         0          0   NaN             3     1Fam       TA
# 11        1182      1142          0   NaN             4     1Fam       TA
# 12         912         0          0   NaN             2     1Fam       TA
# 13        1494         0          0   NaN             3     1Fam       TA
# 14        1253         0          0   NaN             2     1Fam       TA
# 15         854         0          0   NaN             2     1Fam       TA
# 16        1004         0          0   NaN             2     1Fam       TA
# 17        1296         0          0   NaN             2   Duplex      NaN
# 18        1114         0          0   NaN             3     1Fam       TA
# 19        1339         0          0   NaN             3     1Fam       TA
# 20        1158      1218          0   NaN             4     1Fam       TA
# 21        1108         0          0  Grvl             3     1Fam       TA
# 22        1795         0          0   NaN             3     1Fam       TA
# 23        1060         0          0   NaN             3   TwnhsE       TA
# 24        1060         0          0   NaN             3     1Fam       TA
# 25        1600         0          0   NaN             3     1Fam       TA
# 26         900         0          0   NaN             3     1Fam       TA
# 27        1704         0          0   NaN             3     1Fam       TA
# 28        1600         0          0   NaN             2     1Fam       TA
# 29         520         0          0   NaN             1     1Fam       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# 2882       641         0          0   NaN             2     1Fam       TA
# 2883       967       671          0   NaN             4     1Fam       TA
# 2884       729         0          0   NaN             2     1Fam      NaN
# 2885      1060       336          0   NaN             4   2fmCon       TA
# 2886       576       360          0   NaN             2     1Fam       Fa
# 2887      1778         0          0   NaN             2   TwnhsE       TA
# 2888      1646         0          0   NaN             2   TwnhsE       TA
# 2889      1625         0          0   NaN             3     1Fam       TA
# 2890      1664         0          0   NaN             4   Duplex       TA
# 2891      1491         0          0   NaN             3     1Fam       TA
# 2892      1210         0          0   NaN             3     1Fam       TA
# 2893      1650         0          0   NaN             2     1Fam       TA
# 2894      1403         0          0   NaN             2     1Fam       TA
# 2895      1960         0          0   NaN             3     1Fam       Gd
# 2896      1838         0          0   NaN             3     1Fam       TA
# 2897      1600         0          0   NaN             3     1Fam      NaN
# 2898      1368         0          0   NaN             2   Duplex       TA
# 2899       616       688          0   NaN             3   TwnhsE       TA
# 2900       874         0          0   NaN             3     1Fam       TA
# 2901      1652         0          0   NaN             4   Duplex       TA
# 2902       630         0          0   NaN             1    Twnhs       TA
# 2903       546       546          0   NaN             3   TwnhsE       TA
# 2904      1360         0          0   NaN             3     1Fam       TA
# 2905       546       546          0   NaN             3    Twnhs       TA
# 2906       546       546          0   NaN             3    Twnhs       TA
# 2907       546       546          0   NaN             3    Twnhs       TA
# 2908       546       546          0   NaN             3   TwnhsE       TA
# 2909      1224         0          0   NaN             4     1Fam       TA
# 2910       970         0          0   NaN             3     1Fam       TA
# 2911       996      1004          0   NaN             3     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... SalePrice SaleType  \
# 0              No       706.0         0.0  ...  208500.0       WD
# 1              Gd       978.0         0.0  ...  181500.0       WD
# 2              Mn       486.0         0.0  ...  223500.0       WD
# 3              No       216.0         0.0  ...  140000.0       WD
# 4              Av       655.0         0.0  ...  250000.0       WD
# 5              No       732.0         0.0  ...  143000.0       WD
# 6              Av      1369.0         0.0  ...  307000.0       WD
# 7              Mn       859.0        32.0  ...  200000.0       WD
# 8              No         0.0         0.0  ...  129900.0       WD
# 9              No       851.0         0.0  ...  118000.0       WD
# 10             No       906.0         0.0  ...  129500.0       WD
# 11             No       998.0         0.0  ...  345000.0      New
# 12             No       737.0         0.0  ...  144000.0       WD
# 13             Av         0.0         0.0  ...  279500.0      New
# 14             No       733.0         0.0  ...  157000.0       WD
# 15             No         0.0         0.0  ...  132000.0       WD
# 16             No       578.0         0.0  ...  149000.0       WD
# 17            NaN         0.0         0.0  ...   90000.0       WD
# 18             No       646.0         0.0  ...  159000.0       WD
# 19             No       504.0         0.0  ...  139000.0      COD
# 20             Av         0.0         0.0  ...  325300.0      New
# 21             No         0.0         0.0  ...  139400.0       WD
# 22             No         0.0         0.0  ...  230000.0       WD
# 23             No       840.0         0.0  ...  129900.0       WD
# 24             Mn       188.0       668.0  ...  154000.0       WD
# 25             No         0.0         0.0  ...  256300.0       WD
# 26             Mn       234.0       486.0  ...  134800.0       WD
# 27             No      1218.0         0.0  ...  306000.0       WD
# 28             Gd      1277.0         0.0  ...  207500.0       WD
# 29             No         0.0         0.0  ...   68500.0       WD
# ...           ...         ...         ...  ...       ...      ...
# 2882           No         0.0         0.0  ...       NaN       WD
# 2883           No         0.0         0.0  ...       NaN       WD
# 2884          NaN         0.0         0.0  ...       NaN       WD
# 2885           Mn         0.0         0.0  ...       NaN       WD
# 2886           No         0.0         0.0  ...       NaN       WD
# 2887           Gd      1573.0         0.0  ...       NaN      New
# 2888           Gd      1564.0         0.0  ...       NaN       WD
# 2889           Gd       776.0         0.0  ...       NaN       WD
# 2890           Mn         0.0         0.0  ...       NaN       WD
# 2891           No         0.0         0.0  ...       NaN       WD
# 2892           Av       576.0         0.0  ...       NaN       WD
# 2893           Gd       909.0         0.0  ...       NaN       WD
# 2894           Av      1136.0       116.0  ...       NaN       WD
# 2895           Av      1350.0         0.0  ...       NaN      New
# 2896           Gd      1455.0         0.0  ...       NaN      New
# 2897          NaN         0.0         0.0  ...       NaN       WD
# 2898           Gd      1243.0         0.0  ...       NaN       WD
# 2899           Mn         0.0         0.0  ...       NaN       WD
# 2900           No       441.0         0.0  ...       NaN       WD
# 2901           No       149.0         0.0  ...       NaN       WD
# 2902           Av       522.0         0.0  ...       NaN       WD
# 2903           No       252.0         0.0  ...       NaN       WD
# 2904           Av       119.0       344.0  ...       NaN       WD
# 2905           No       408.0         0.0  ...       NaN       WD
# 2906           No         0.0         0.0  ...       NaN       WD
# 2907           No         0.0         0.0  ...       NaN       WD
# 2908           No       252.0         0.0  ...       NaN       WD
# 2909           No      1224.0         0.0  ...       NaN       WD
# 2910           Av       337.0         0.0  ...       NaN       WD
# 2911           Av       758.0         0.0  ...       NaN       WD
#
#       ScreenPorch  Street TotRmsAbvGrd  TotalBsmtSF WoodDeckSF YearBuilt  \
# 0               0    Pave            8        856.0          0      2003
# 1               0    Pave            6       1262.0        298      1976
# 2               0    Pave            6        920.0          0      2001
# 3               0    Pave            7        756.0          0      1915
# 4               0    Pave            9       1145.0        192      2000
# 5               0    Pave            5        796.0         40      1993
# 6               0    Pave            7       1686.0        255      2004
# 7               0    Pave            7       1107.0        235      1973
# 8               0    Pave            8        952.0         90      1931
# 9               0    Pave            5        991.0          0      1939
# 10              0    Pave            5       1040.0          0      1965
# 11              0    Pave           11       1175.0        147      2005
# 12            176    Pave            4        912.0        140      1962
# 13              0    Pave            7       1494.0        160      2006
# 14              0    Pave            5       1253.0          0      1960
# 15              0    Pave            5        832.0         48      1929
# 16              0    Pave            5       1004.0          0      1970
# 17              0    Pave            6          0.0          0      1967
# 18              0    Pave            6       1114.0          0      2004
# 19              0    Pave            6       1029.0          0      1958
# 20              0    Pave            9       1158.0        240      2005
# 21              0    Pave            6        637.0          0      1930
# 22              0    Pave            7       1777.0        171      2002
# 23              0    Pave            6       1040.0        100      1976
# 24              0    Pave            6       1060.0        406      1968
# 25              0    Pave            7       1566.0          0      2007
# 26              0    Pave            5        900.0        222      1951
# 27              0    Pave            7       1704.0          0      2007
# 28              0    Pave            6       1484.0        288      1957
# 29              0    Pave            4        520.0         49      1927
# ...           ...     ...          ...          ...        ...       ...
# 2882            0    Pave            4        641.0        184      1925
# 2883            0    Pave            6        967.0          0      1957
# 2884            0    Pave            5          0.0          0      1945
# 2885            0    Pave            8        660.0          0      1951
# 2886            0    Grvl            6        216.0          0      1916
# 2887          153    Pave            5       1573.0        123      2005
# 2888          155    Pave            5       1594.0        128      2004
# 2889            0    Pave            6       1625.0        136      1979
# 2890            0    Pave           10       1664.0          0      1978
# 2891            0    Pave            7       1491.0        120      2001
# 2892            0    Pave            6       1128.0          0      1975
# 2893          138    Pave            6       1632.0          0      1958
# 2894            0    Pave            5       1381.0          0      2000
# 2895            0    Pave            8       1728.0        172      2005
# 2896            0    Pave            9       1838.0        161      2005
# 2897            0    Pave            6          0.0          0      1951
# 2898            0    Pave            8       1288.0          0      1997
# 2899            0    Pave            5        264.0        141      1977
# 2900            0    Pave            5        864.0          0      1968
# 2901            0    Pave            8       1652.0          0      1970
# 2902            0    Pave            3        630.0          0      1970
# 2903            0    Pave            5        546.0          0      1972
# 2904            0    Pave            8       1104.0        160      1969
# 2905            0    Pave            5        546.0          0      1970
# 2906            0    Pave            5        546.0          0      1970
# 2907            0    Pave            5        546.0          0      1970
# 2908            0    Pave            6        546.0          0      1970
# 2909            0    Pave            7       1224.0        474      1960
# 2910            0    Pave            6        912.0         80      1992
# 2911            0    Pave            9        996.0        190      1993
#
#      YearRemodAdd YrSold
# 0            2003   2008
# 1            1976   2007
# 2            2002   2008
# 3            1970   2006
# 4            2000   2008
# 5            1995   2009
# 6            2005   2007
# 7            1973   2009
# 8            1950   2008
# 9            1950   2008
# 10           1965   2008
# 11           2006   2006
# 12           1962   2008
# 13           2007   2007
# 14           1960   2008
# 15           2001   2007
# 16           1970   2010
# 17           1967   2006
# 18           2004   2008
# 19           1965   2009
# 20           2006   2006
# 21           1950   2007
# 22           2002   2008
# 23           1976   2007
# 24           2001   2010
# 25           2007   2009
# 26           2000   2010
# 27           2008   2010
# 28           1997   2006
# 29           1950   2008
# ...           ...    ...
# 2882         1950   2006
# 2883         1957   2006
# 2884         1950   2006
# 2885         1951   2006
# 2886         1950   2006
# 2887         2006   2006
# 2888         2005   2006
# 2889         1979   2006
# 2890         1978   2006
# 2891         2001   2006
# 2892         1975   2006
# 2893         1958   2006
# 2894         2000   2006
# 2895         2006   2006
# 2896         2006   2006
# 2897         1951   2006
# 2898         1997   2006
# 2899         1977   2006
# 2900         2003   2006
# 2901         1970   2006
# 2902         1970   2006
# 2903         1972   2006
# 2904         1979   2006
# 2905         1970   2006
# 2906         1970   2006
# 2907         1970   2006
# 2908         1970   2006
# 2909         1996   2006
# 2910         1992   2006
# 2911         1994   2006
#
# [2912 rows x 79 columns]

# %%
data[cat].apply(lambda x: [x.unique()])
# Out:
# CentralAir                                                [[Y, N]]
# HouseStyle       [[2Story, 1Story, 1.5Fin, 1.5Unf, SFoyer, SLvl...
# ExterCond                                   [[TA, Gd, Fa, Po, Ex]]
# Utilities                                  [[AllPub, NoSeWa, nan]]
# BsmtExposure                               [[No, Gd, Mn, Av, nan]]
# Neighborhood     [[CollgCr, Veenker, Crawfor, NoRidge, Mitchel,...
# Functional          [[Typ, Min1, Maj1, Min2, Mod, Maj2, Sev, nan]]
# YrSold                            [[2008, 2007, 2006, 2009, 2010]]
# MSZoning                          [[RL, RM, C (all), FV, RH, nan]]
# FireplaceQu                            [[nan, TA, Gd, Fa, Ex, Po]]
# Foundation            [[PConc, CBlock, BrkTil, Wood, Slab, Stone]]
# SaleType         [[WD, New, COD, ConLD, ConLI, CWD, ConLw, Con,...
# Street                                              [[Pave, Grvl]]
# Electrical                [[SBrkr, FuseF, FuseA, FuseP, Mix, nan]]
# GarageQual                             [[TA, Fa, Gd, nan, Ex, Po]]
# YearBuilt        [[2003, 1976, 2001, 1915, 2000, 1993, 2004, 19...
# MoSold                   [[2, 5, 9, 12, 10, 8, 11, 4, 1, 7, 3, 6]]
# Condition2       [[Norm, Artery, RRNn, Feedr, PosA, PosN, RRAn,...
# RoofStyle             [[Gable, Hip, Gambrel, Mansard, Flat, Shed]]
# BsmtCond                                   [[TA, Gd, nan, Fa, Po]]
# OverallCond                          [[5, 8, 6, 7, 4, 2, 3, 9, 1]]
# MasVnrType                   [[BrkFace, None, Stone, BrkCmn, nan]]
# BsmtFinType2                 [[Unf, BLQ, nan, ALQ, Rec, LwQ, GLQ]]
# MiscFeature                        [[nan, Shed, Gar2, Othr, TenC]]
# LandSlope                                        [[Gtl, Mod, Sev]]
# Fence                            [[nan, MnPrv, GdWo, GdPrv, MnWw]]
# Alley                                          [[nan, Grvl, Pave]]
# Heating                    [[GasA, GasW, Grav, Wall, OthW, Floor]]
# PoolQC                                         [[nan, Ex, Fa, Gd]]
# PavedDrive                                             [[Y, N, P]]
# GarageFinish                                [[RFn, Unf, Fin, nan]]
# OverallQual                      [[7, 6, 8, 5, 9, 4, 10, 3, 1, 2]]
# ExterQual                                       [[Gd, TA, Ex, Fa]]
# MSSubClass       [[60, 20, 70, 50, 190, 45, 90, 120, 30, 85, 80...
# Exterior2nd      [[VinylSd, MetalSd, Wd Shng, HdBoard, Plywood,...
# BldgType                   [[1Fam, 2fmCon, Duplex, TwnhsE, Twnhs]]
# Exterior1st      [[VinylSd, MetalSd, Wd Sdng, HdBoard, BrkFace,...
# GarageCond                             [[TA, Fa, nan, Gd, Po, Ex]]
# GarageYrBlt      [[2003.0, 1976.0, 2001.0, 1998.0, 2000.0, 1993...
# YearRemodAdd     [[2003, 1976, 2002, 1970, 2000, 1995, 2005, 19...
# LotConfig                    [[Inside, FR2, Corner, CulDSac, FR3]]
# SaleCondition    [[Normal, Abnorml, Partial, AdjLand, Alloca, F...
# RoofMatl         [[CompShg, WdShngl, Metal, WdShake, Membran, T...
# LotShape                                    [[Reg, IR1, IR2, IR3]]
# GarageType       [[Attchd, Detchd, BuiltIn, CarPort, nan, Basme...
# BsmtFinType1                 [[GLQ, ALQ, Unf, Rec, BLQ, nan, LwQ]]
# BsmtQual                                   [[Gd, TA, Ex, nan, Fa]]
# LandContour                                 [[Lvl, Bnk, Low, HLS]]
# HeatingQC                                   [[Ex, Gd, TA, Fa, Po]]
# KitchenQual                                [[Gd, TA, Ex, Fa, nan]]
# Condition1       [[Norm, Feedr, PosN, Artery, RRAe, RRNn, RRAn,...
# dtype: object

# %%
#Total:2,912
has_null = data.columns[data.isnull().any(axis = 0)]

no_nulls = data[has_null].apply(lambda x: x.isnull().sum())
nulls_perc = data[has_null].apply(lambda x: x.isnull().sum()/2912)

has_nulls = pd.concat([no_nulls, nulls_perc], axis=1)
has_nulls.columns = ['nulls', 'percent']
has_nulls.sort_values('nulls', ascending = False)
has_nulls[has_nulls.percent > 0.1].sort_values('nulls', ascending = False)
# Out:
#              nulls   percent
# PoolQC        2903  0.996909
# MiscFeature   2808  0.964286
# Alley         2715  0.932349
# Fence         2341  0.803915
# SalePrice     1459  0.501030
# FireplaceQu   1417  0.486607
# LotFrontage    485  0.166552

# %%
data.loc[data.PoolArea == 0, ['PoolQC']] = 'NA'
data.loc[data.PoolArea > 0, ['OverallQual','PoolArea', 'PoolQC']].sort_values('PoolQC')
# Out:
#       OverallQual  PoolArea PoolQC
# 197             8       512     Ex
# 1178           10       555     Ex
# 1967           10       144     Ex
# 2566            8       228     Ex
# 807             6       648     Fa
# 1379            7       519     Fa
# 1166            6       576     Gd
# 1416            6       738     Gd
# 2703            7       800     Gd
# 2413            4       368    NaN
# 2496            6       444    NaN
# 2592            3       561    NaN

# %%
#        Ex	Excellent >5
#        Gd	Good 4
#        TA	Average/Typical 3
#        Fa	Fair 2
#        NA	No Pool 0
(data.OverallQual[data.PoolArea > 0]/2).round().unique()
data['poolQual'] = (data.OverallQual/2).round()
qual = {2: 'Fa', 3: 'TA', 4: 'Gd', 5: 'Ex'}

data.loc[(data.PoolArea>0) & (data.PoolQC.isnull()), ['PoolQC']] = (data.loc[(data.PoolArea>0) & (data.PoolQC.isnull()),  ['OverallQual']]/2).round().apply(lambda x: x.map(qual))

# %%
data.loc[data.MiscFeature.isnull(), ['MiscFeature']] = 'NA'
data.loc[data.Alley.isnull(), ['Alley']] = 'NA'
data.loc[data.Fence.isnull(), ['Fence']] = 'NA'

# %%
data.loc[(data.Fireplaces == 0), ['FireplaceQu']] = 'NA'
data.loc[data.SalePrice.isnull(), ['SalePrice']] = 0

# %%
lotmean = data.groupby('Neighborhood').LotFrontage.mean()
data.loc[data.LotFrontage.isnull(), ['LotFrontage']] = data.loc[data.LotFrontage.isnull(), ['Neighborhood', 'LotFrontage']].apply(lambda x: lotmean[x.Neighborhood], axis=1)

# %%
#impute
fill = pd.Series([data[c].value_counts().index[0]
            if c in cat else data[c].mean() for c in data],
            index=data.columns)

data = data.fillna(fill)

# %%
data[cat].apply(lambda x: [x.unique()])
# Out:
# CentralAir                                                [[Y, N]]
# HouseStyle       [[2Story, 1Story, 1.5Fin, 1.5Unf, SFoyer, SLvl...
# ExterCond                                   [[TA, Gd, Fa, Po, Ex]]
# Utilities                                       [[AllPub, NoSeWa]]
# BsmtExposure                                    [[No, Gd, Mn, Av]]
# Neighborhood     [[CollgCr, Veenker, Crawfor, NoRidge, Mitchel,...
# Functional               [[Typ, Min1, Maj1, Min2, Mod, Maj2, Sev]]
# YrSold                            [[2008, 2007, 2006, 2009, 2010]]
# MSZoning                               [[RL, RM, C (all), FV, RH]]
# FireplaceQu                             [[NA, TA, Gd, Fa, Ex, Po]]
# Foundation            [[PConc, CBlock, BrkTil, Wood, Slab, Stone]]
# SaleType         [[WD, New, COD, ConLD, ConLI, CWD, ConLw, Con,...
# Street                                              [[Pave, Grvl]]
# Electrical                     [[SBrkr, FuseF, FuseA, FuseP, Mix]]
# GarageQual                                  [[TA, Fa, Gd, Ex, Po]]
# YearBuilt        [[2003, 1976, 2001, 1915, 2000, 1993, 2004, 19...
# MoSold                   [[2, 5, 9, 12, 10, 8, 11, 4, 1, 7, 3, 6]]
# Condition2       [[Norm, Artery, RRNn, Feedr, PosA, PosN, RRAn,...
# RoofStyle             [[Gable, Hip, Gambrel, Mansard, Flat, Shed]]
# BsmtCond                                        [[TA, Gd, Fa, Po]]
# OverallCond                          [[5, 8, 6, 7, 4, 2, 3, 9, 1]]
# MasVnrType                        [[BrkFace, None, Stone, BrkCmn]]
# BsmtFinType2                      [[Unf, BLQ, ALQ, Rec, LwQ, GLQ]]
# MiscFeature                         [[NA, Shed, Gar2, Othr, TenC]]
# LandSlope                                        [[Gtl, Mod, Sev]]
# Fence                             [[NA, MnPrv, GdWo, GdPrv, MnWw]]
# Alley                                           [[NA, Grvl, Pave]]
# Heating                    [[GasA, GasW, Grav, Wall, OthW, Floor]]
# PoolQC                                          [[NA, Ex, Fa, Gd]]
# PavedDrive                                             [[Y, N, P]]
# GarageFinish                                     [[RFn, Unf, Fin]]
# OverallQual                      [[7, 6, 8, 5, 9, 4, 10, 3, 1, 2]]
# ExterQual                                       [[Gd, TA, Ex, Fa]]
# MSSubClass       [[60, 20, 70, 50, 190, 45, 90, 120, 30, 85, 80...
# Exterior2nd      [[VinylSd, MetalSd, Wd Shng, HdBoard, Plywood,...
# BldgType                   [[1Fam, 2fmCon, Duplex, TwnhsE, Twnhs]]
# Exterior1st      [[VinylSd, MetalSd, Wd Sdng, HdBoard, BrkFace,...
# GarageCond                                  [[TA, Fa, Gd, Po, Ex]]
# GarageYrBlt      [[2003.0, 1976.0, 2001.0, 1998.0, 2000.0, 1993...
# YearRemodAdd     [[2003, 1976, 2002, 1970, 2000, 1995, 2005, 19...
# LotConfig                    [[Inside, FR2, Corner, CulDSac, FR3]]
# SaleCondition    [[Normal, Abnorml, Partial, AdjLand, Alloca, F...
# RoofMatl         [[CompShg, WdShngl, Metal, WdShake, Membran, T...
# LotShape                                    [[Reg, IR1, IR2, IR3]]
# GarageType       [[Attchd, Detchd, BuiltIn, CarPort, Basment, 2...
# BsmtFinType1                      [[GLQ, ALQ, Unf, Rec, BLQ, LwQ]]
# BsmtQual                                        [[Gd, TA, Ex, Fa]]
# LandContour                                 [[Lvl, Bnk, Low, HLS]]
# HeatingQC                                   [[Ex, Gd, TA, Fa, Po]]
# KitchenQual                                     [[Gd, TA, Ex, Fa]]
# Condition1       [[Norm, Feedr, PosN, Artery, RRAe, RRNn, RRAn,...
# dtype: object

# %%
sum(data.isnull().sum())
# Out:
# 0

# %%
cont = cont + ['MoSold', 'YearBuilt', 'OverallCond', 'MSSubClass', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']
cat = list(set(data.columns) - set(cont))

# %%
le = LabelEncoder()

for i in cat:
    data[i] = le.fit_transform(data[i])

# %%
# train = data.loc[data.SalePrice > 0]
# corr = train.corr()
corr[abs(corr.SalePrice) > 0.2].keys()
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley', 'BedroomAbvGr',
#        'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath',
#        'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st',
#        'Exterior2nd', 'Fence', 'FireplaceQu', 'Fireplaces', 'Foundation',
#        'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt', 'GrLivArea',
#        'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenAbvGr',
#        'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig',
#        'LotFrontage', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning',
#        'MasVnrArea', 'MasVnrType', 'MiscFeature', 'MiscVal', 'MoSold',
#        'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual',
#        'PavedDrive', 'PoolArea', 'PoolQC', 'RoofMatl', 'RoofStyle',
#        'SaleCondition', 'SalePrice', 'SaleType', 'ScreenPorch', 'Street',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object')
